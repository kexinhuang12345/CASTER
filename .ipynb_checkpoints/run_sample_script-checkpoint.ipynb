# %%
import os
os.chdir('./DDE')

import torch
from torch.autograd import Variable
import torch.nn.functional as F
from torch.utils import data
from torch import nn 
import copy

from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from time import time
from sklearn.metrics import roc_auc_score, precision_recall_curve
from sklearn.model_selection import KFold
torch.manual_seed(2)    # reproducible torch:2 np:3
np.random.seed(3)

from dde_config import dde_NN_config
from dde_torch import dde_NN_Large_Predictor
from stream_dde import supData, unsupData

use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
def test_dde_nn(data_generator, model_nn):
    y_pred = []
    y_label = []
    model_nn.eval()
    for i, (v_D, label) in enumerate(data_generator):
        recon, code, score, Z_f, z_D = model_nn(v_D.float().cuda())
        m = torch.nn.Sigmoid()
        logits = torch.squeeze(m(score)).detach().cpu().numpy()
        label_ids = label.to('cpu').numpy()
        y_label = y_label + label_ids.flatten().tolist()
        y_pred = y_pred + logits.flatten().tolist()

    return roc_auc_score(y_label, y_pred), y_pred


def main_dde_nn():
    config = dde_NN_config()
    pretrain_epoch = config['pretrain_epoch']
    pretrain_epoch = 0
    train_epoch = 9
    lr = config['LR']
    thr = config['recon_threshold']
    recon_loss_coeff = config['reconstruction_coefficient']
    proj_coeff = config['projection_coefficient']
    lambda1 = config['lambda1']
    lambda2 = config['lambda2']
    BATCH_SIZE = config['batch_size']
    
    loss_r_history = []
    loss_p_history = []
    loss_c_history = []
    loss_history = []
    
    #model_nn = dde_NN_Large_Predictor(**config)
    path = 'model_pretrain_checkpoint_1.pt'
    model_nn = torch.load(path)
    
    model_nn.cuda()
    
    if torch.cuda.device_count() > 1:
        print("Let's use", torch.cuda.device_count(), "GPUs!")
        model_nn = nn.DataParallel(model_nn)
        
    opt = torch.optim.Adam(model_nn.parameters(), lr = lr)
    
    print('--- Data Preparation ---')
    
    params = {'batch_size': BATCH_SIZE,
              'shuffle': True,
              'num_workers': 6}

    dataFolder = './data'

    df_unsup = pd.read_csv(dataFolder + '/unsup_dataset.csv', names = ['idx', 'input1_SMILES', 'input2_SMILES', 'type']).drop(0)# pairs dataframe input1_smiles, input2_smiles
    df_ddi = pd.read_csv('../data/SNAP/sup_train_val.csv')  # ddi dataframe drug1_smiles, drug2_smiles

    #5-fold
    kf = KFold(n_splits = 8, shuffle = True, random_state = 3)
    #get the 1st fold index
    fold_index = next(kf.split(df_ddi), None)

    ids_unsup = df_unsup.index.values
    partition_sup = {'train': fold_index[0], 'val': fold_index[1]}
    labels_sup = df_ddi.label.values

    unsup_set = unsupData(ids_unsup, df_unsup)
    unsup_generator = data.DataLoader(unsup_set, **params)

    training_set = supData(partition_sup['train'], labels_sup, df_ddi)
    training_generator_sup = data.DataLoader(training_set, **params)

    validation_set = supData(partition_sup['val'], labels_sup, df_ddi)
    validation_generator_sup = data.DataLoader(validation_set, **params)
    
    max_auc = 0
    model_max = copy.deepcopy(model_nn)
    
    print('--- Pre-training Starts ---')
    torch.backends.cudnn.benchmark = True
    len_unsup = len(unsup_generator)
    for pre_epo in range(pretrain_epoch):
        for i, v_D in enumerate(unsup_generator):
            v_D = v_D.float().cuda()
            recon, code, score, Z_f, z_D = model_nn(v_D)
            loss_r = recon_loss_coeff * F.binary_cross_entropy(recon, v_D.float())
            
            loss_p = proj_coeff * (torch.norm(z_D - torch.matmul(code, Z_f)) + lambda1 * torch.sum(torch.abs(code)) / BATCH_SIZE + lambda2 * torch.norm(Z_f, p='fro') / BATCH_SIZE)
            loss = loss_r + loss_p
            
            loss_r_history.append(loss_r)
            loss_p_history.append(loss_p)
            loss_history.append(loss)

            opt.zero_grad()
            loss.backward()
            opt.step()
            
            if(i % 10 == 0):
                print('Pre-Training at Epoch ' + str(pre_epo) + ' iteration ' + str(i) + ', total loss is '
                      + '%.3f' % (loss.cpu().detach().numpy()) + ', proj loss is ' + '%.3f' % (loss_p.cpu().detach().numpy()) 
                      + ', recon loss is ' + '%.3f' % (loss_r.cpu().detach().numpy()))

            if loss_r < thr:
                # smaller than certain reconstruction error, -> go to training step
                break
        
            if i == int(len_unsup/4):
                torch.save(model_nn, 'model_pretrain_checkpoint_1.pt')
            if i == int(len_unsup/2):
                torch.save(model_nn, 'model_pretrain_checkpoint_1.pt')
        torch.save(model_nn, 'model_nn_pretrain.pt')
            
    print('--- Go for Training ---')
    
    for tr_epo in range(train_epoch):
        for i, (v_D, label) in enumerate(training_generator_sup):
            v_D = v_D.float().cuda()
            recon, code, score, Z_f, z_D = model_nn(v_D)
            
            label = Variable(torch.from_numpy(np.array(label)).long())
            loss_fct = torch.nn.BCELoss()
            m = torch.nn.Sigmoid()
            n = torch.squeeze(m(score))
            
            loss_c = loss_fct(n, label.float().cuda())
            loss_r = recon_loss_coeff * F.binary_cross_entropy(recon, v_D.float())
            
            loss_p = proj_coeff * (torch.norm(z_D - torch.matmul(code, Z_f)) + lambda1 * torch.sum(torch.abs(code)) / BATCH_SIZE + lambda2 * torch.norm(Z_f, p='fro') / BATCH_SIZE)
            
            loss = loss_c + loss_r + loss_p
            loss_r_history.append(loss_r)
            loss_p_history.append(loss_p)
            loss_c_history.append(loss_c)
            loss_history.append(loss)

            opt.zero_grad()
            loss.backward()
            opt.step()
                    
            if(i % 20 == 0):
                print('Training at Epoch ' + str(tr_epo) + ' iteration ' + str(i) + ', total loss is ' + '%.3f' % (loss.cpu().detach().numpy()) + ', proj loss is ' + '%.3f' %(loss_p.cpu().detach().numpy()) + ', recon loss is ' + '%.3f' %(loss_r.cpu().detach().numpy()) + ', classification loss is ' + '%.3f' % (loss_c.cpu().detach().numpy()))
            
        with torch.set_grad_enabled(False):
            auc, logits = test_dde_nn(validation_generator_sup, model_nn)
            if auc > max_auc:
                model_max = copy.deepcopy(model_nn)
                max_auc = auc
                path = 'model_train_checkpoint_SNAP_EarlyStopping_SemiSup_Full_Run3.pt'
                torch.save(model_nn, path)    
            print('Test at Epoch '+ str(tr_epo) + ' , AUC: '+ str(auc))
        
    return model_max, loss_c_history, loss_r_history, loss_p_history

# %%
 if __name__ == '__main__':
    model_max, loss_c, loss_r, loss_p = main_dde_nn()
    pass
# Out:
# /home/kh2383/pytorch-gpu/py3.6.3/lib/python3.6/site-packages/torch/serialization.py:435: SourceChangeWarning: source code of class 'dde_torch.dde_NN_Large_Predictor' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# --- Data Preparation ---
# /share/apps/python3/3.6.3/intel/lib/python3.6/site-packages/ipython-6.2.1-py3.6.egg/IPython/core/interactiveshell.py:2850: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# --- Pre-training Starts ---
# --- Go for Training ---
# Training at Epoch 0 iteration 0, total loss is 0.713, proj loss is 0.010, recon loss is 0.005, classification loss is 0.697
# Training at Epoch 0 iteration 20, total loss is 0.669, proj loss is 0.079, recon loss is 0.005, classification loss is 0.585
# Training at Epoch 0 iteration 40, total loss is 0.654, proj loss is 0.051, recon loss is 0.005, classification loss is 0.597
# Training at Epoch 0 iteration 60, total loss is 0.646, proj loss is 0.058, recon loss is 0.005, classification loss is 0.583
# Training at Epoch 0 iteration 80, total loss is 0.590, proj loss is 0.055, recon loss is 0.005, classification loss is 0.530
# Training at Epoch 0 iteration 100, total loss is 0.596, proj loss is 0.068, recon loss is 0.005, classification loss is 0.524
# Training at Epoch 0 iteration 120, total loss is 0.641, proj loss is 0.064, recon loss is 0.005, classification loss is 0.571
# Training at Epoch 0 iteration 140, total loss is 0.503, proj loss is 0.057, recon loss is 0.005, classification loss is 0.441
# Training at Epoch 0 iteration 160, total loss is 0.621, proj loss is 0.073, recon loss is 0.005, classification loss is 0.543
# Training at Epoch 0 iteration 180, total loss is 0.616, proj loss is 0.082, recon loss is 0.005, classification loss is 0.528
# Training at Epoch 0 iteration 200, total loss is 0.604, proj loss is 0.062, recon loss is 0.005, classification loss is 0.538
# Test at Epoch 0 , AUC: 0.837177094313
# Training at Epoch 1 iteration 0, total loss is 0.581, proj loss is 0.076, recon loss is 0.005, classification loss is 0.500
# Training at Epoch 1 iteration 20, total loss is 0.548, proj loss is 0.066, recon loss is 0.005, classification loss is 0.478
# Training at Epoch 1 iteration 40, total loss is 0.554, proj loss is 0.080, recon loss is 0.005, classification loss is 0.469
# Training at Epoch 1 iteration 60, total loss is 0.546, proj loss is 0.077, recon loss is 0.005, classification loss is 0.464
# Training at Epoch 1 iteration 80, total loss is 0.572, proj loss is 0.070, recon loss is 0.005, classification loss is 0.497
# Training at Epoch 1 iteration 100, total loss is 0.523, proj loss is 0.062, recon loss is 0.005, classification loss is 0.457
# Training at Epoch 1 iteration 120, total loss is 0.553, proj loss is 0.059, recon loss is 0.005, classification loss is 0.490
# Training at Epoch 1 iteration 140, total loss is 0.562, proj loss is 0.063, recon loss is 0.005, classification loss is 0.494
# Training at Epoch 1 iteration 160, total loss is 0.456, proj loss is 0.057, recon loss is 0.005, classification loss is 0.395
# Training at Epoch 1 iteration 180, total loss is 0.562, proj loss is 0.072, recon loss is 0.005, classification loss is 0.486
# Training at Epoch 1 iteration 200, total loss is 0.504, proj loss is 0.075, recon loss is 0.005, classification loss is 0.423
# Test at Epoch 1 , AUC: 0.86287254308
# Training at Epoch 2 iteration 0, total loss is 0.478, proj loss is 0.057, recon loss is 0.005, classification loss is 0.416
# Training at Epoch 2 iteration 20, total loss is 0.396, proj loss is 0.063, recon loss is 0.005, classification loss is 0.329
# Training at Epoch 2 iteration 40, total loss is 0.435, proj loss is 0.093, recon loss is 0.005, classification loss is 0.336
# Training at Epoch 2 iteration 60, total loss is 0.433, proj loss is 0.051, recon loss is 0.005, classification loss is 0.377
# Training at Epoch 2 iteration 80, total loss is 0.472, proj loss is 0.086, recon loss is 0.005, classification loss is 0.382
# Training at Epoch 2 iteration 100, total loss is 0.470, proj loss is 0.061, recon loss is 0.005, classification loss is 0.404
# Training at Epoch 2 iteration 120, total loss is 0.470, proj loss is 0.085, recon loss is 0.005, classification loss is 0.380
# Training at Epoch 2 iteration 140, total loss is 0.488, proj loss is 0.067, recon loss is 0.005, classification loss is 0.416
# Training at Epoch 2 iteration 160, total loss is 0.460, proj loss is 0.060, recon loss is 0.005, classification loss is 0.394
# Training at Epoch 2 iteration 180, total loss is 0.416, proj loss is 0.057, recon loss is 0.005, classification loss is 0.354
# Training at Epoch 2 iteration 200, total loss is 0.459, proj loss is 0.065, recon loss is 0.005, classification loss is 0.389
# Test at Epoch 2 , AUC: 0.881128260823
# Training at Epoch 3 iteration 0, total loss is 0.406, proj loss is 0.063, recon loss is 0.005, classification loss is 0.338
# Training at Epoch 3 iteration 20, total loss is 0.541, proj loss is 0.135, recon loss is 0.005, classification loss is 0.401
# Training at Epoch 3 iteration 40, total loss is 0.413, proj loss is 0.106, recon loss is 0.005, classification loss is 0.302
# Training at Epoch 3 iteration 60, total loss is 0.339, proj loss is 0.070, recon loss is 0.005, classification loss is 0.264
# Training at Epoch 3 iteration 80, total loss is 0.385, proj loss is 0.076, recon loss is 0.005, classification loss is 0.304
# Training at Epoch 3 iteration 100, total loss is 0.447, proj loss is 0.074, recon loss is 0.005, classification loss is 0.368
# Training at Epoch 3 iteration 120, total loss is 0.404, proj loss is 0.061, recon loss is 0.005, classification loss is 0.338
# Training at Epoch 3 iteration 140, total loss is 0.443, proj loss is 0.086, recon loss is 0.005, classification loss is 0.352
# Training at Epoch 3 iteration 160, total loss is 0.458, proj loss is 0.099, recon loss is 0.005, classification loss is 0.354
# Training at Epoch 3 iteration 180, total loss is 0.407, proj loss is 0.080, recon loss is 0.005, classification loss is 0.322
# Training at Epoch 3 iteration 200, total loss is 0.465, proj loss is 0.078, recon loss is 0.005, classification loss is 0.382
# Test at Epoch 3 , AUC: 0.89778189387
# Training at Epoch 4 iteration 0, total loss is 0.722, proj loss is 0.427, recon loss is 0.005, classification loss is 0.290
# Training at Epoch 4 iteration 20, total loss is 0.273, proj loss is 0.070, recon loss is 0.005, classification loss is 0.198
# Training at Epoch 4 iteration 40, total loss is 0.347, proj loss is 0.059, recon loss is 0.005, classification loss is 0.283
# Training at Epoch 4 iteration 60, total loss is 0.396, proj loss is 0.068, recon loss is 0.005, classification loss is 0.323
# Training at Epoch 4 iteration 80, total loss is 0.486, proj loss is 0.084, recon loss is 0.005, classification loss is 0.397
# Training at Epoch 4 iteration 100, total loss is 0.333, proj loss is 0.061, recon loss is 0.005, classification loss is 0.267
# Training at Epoch 4 iteration 120, total loss is 0.409, proj loss is 0.095, recon loss is 0.005, classification loss is 0.309
# Training at Epoch 4 iteration 140, total loss is 0.327, proj loss is 0.070, recon loss is 0.005, classification loss is 0.252
# Training at Epoch 4 iteration 160, total loss is 0.375, proj loss is 0.064, recon loss is 0.005, classification loss is 0.306
# Training at Epoch 4 iteration 180, total loss is 0.423, proj loss is 0.086, recon loss is 0.005, classification loss is 0.332
# Training at Epoch 4 iteration 200, total loss is 0.380, proj loss is 0.061, recon loss is 0.005, classification loss is 0.314
# Test at Epoch 4 , AUC: 0.900270860837
# Training at Epoch 5 iteration 0, total loss is 0.351, proj loss is 0.051, recon loss is 0.005, classification loss is 0.295
# Training at Epoch 5 iteration 20, total loss is 0.306, proj loss is 0.115, recon loss is 0.005, classification loss is 0.186
# Training at Epoch 5 iteration 40, total loss is 0.331, proj loss is 0.078, recon loss is 0.005, classification loss is 0.247
# Training at Epoch 5 iteration 60, total loss is 0.343, proj loss is 0.037, recon loss is 0.005, classification loss is 0.301
# Training at Epoch 5 iteration 80, total loss is 0.436, proj loss is 0.201, recon loss is 0.005, classification loss is 0.230
# Training at Epoch 5 iteration 100, total loss is 0.236, proj loss is 0.061, recon loss is 0.005, classification loss is 0.171
# Training at Epoch 5 iteration 120, total loss is 0.367, proj loss is 0.040, recon loss is 0.005, classification loss is 0.322
# Training at Epoch 5 iteration 140, total loss is 0.385, proj loss is 0.094, recon loss is 0.005, classification loss is 0.287
# Training at Epoch 5 iteration 160, total loss is 0.328, proj loss is 0.063, recon loss is 0.005, classification loss is 0.260
# Training at Epoch 5 iteration 180, total loss is 0.364, proj loss is 0.105, recon loss is 0.005, classification loss is 0.254
# Training at Epoch 5 iteration 200, total loss is 0.338, proj loss is 0.124, recon loss is 0.005, classification loss is 0.210
# Test at Epoch 5 , AUC: 0.902662966728
# Training at Epoch 6 iteration 0, total loss is 0.286, proj loss is 0.098, recon loss is 0.005, classification loss is 0.183
# Training at Epoch 6 iteration 20, total loss is 0.309, proj loss is 0.111, recon loss is 0.005, classification loss is 0.193
# Training at Epoch 6 iteration 40, total loss is 0.327, proj loss is 0.098, recon loss is 0.005, classification loss is 0.225
# Training at Epoch 6 iteration 60, total loss is 0.540, proj loss is 0.315, recon loss is 0.005, classification loss is 0.220
# Training at Epoch 6 iteration 80, total loss is 0.270, proj loss is 0.061, recon loss is 0.005, classification loss is 0.204
# Training at Epoch 6 iteration 100, total loss is 0.291, proj loss is 0.099, recon loss is 0.005, classification loss is 0.188
# Training at Epoch 6 iteration 120, total loss is 0.294, proj loss is 0.036, recon loss is 0.005, classification loss is 0.253
# Training at Epoch 6 iteration 140, total loss is 0.262, proj loss is 0.031, recon loss is 0.005, classification loss is 0.226
# Training at Epoch 6 iteration 160, total loss is 0.247, proj loss is 0.043, recon loss is 0.005, classification loss is 0.199
# Training at Epoch 6 iteration 180, total loss is 0.311, proj loss is 0.072, recon loss is 0.005, classification loss is 0.233
# Training at Epoch 6 iteration 200, total loss is 0.314, proj loss is 0.091, recon loss is 0.005, classification loss is 0.218
# Test at Epoch 6 , AUC: 0.905150620536
# Training at Epoch 7 iteration 0, total loss is 0.323, proj loss is 0.151, recon loss is 0.005, classification loss is 0.167
# Training at Epoch 7 iteration 20, total loss is 0.257, proj loss is 0.101, recon loss is 0.005, classification loss is 0.151
# Training at Epoch 7 iteration 40, total loss is 0.308, proj loss is 0.153, recon loss is 0.005, classification loss is 0.151
# Training at Epoch 7 iteration 60, total loss is 0.251, proj loss is 0.065, recon loss is 0.005, classification loss is 0.181
# Training at Epoch 7 iteration 80, total loss is 0.280, proj loss is 0.071, recon loss is 0.005, classification loss is 0.204
# Training at Epoch 7 iteration 100, total loss is 0.266, proj loss is 0.056, recon loss is 0.005, classification loss is 0.204
# Training at Epoch 7 iteration 120, total loss is 0.284, proj loss is 0.078, recon loss is 0.005, classification loss is 0.201
# Training at Epoch 7 iteration 140, total loss is 0.239, proj loss is 0.061, recon loss is 0.005, classification loss is 0.173
# Training at Epoch 7 iteration 160, total loss is 0.191, proj loss is 0.044, recon loss is 0.005, classification loss is 0.142
# Training at Epoch 7 iteration 180, total loss is 0.280, proj loss is 0.026, recon loss is 0.005, classification loss is 0.249
# Training at Epoch 7 iteration 200, total loss is 0.280, proj loss is 0.065, recon loss is 0.005, classification loss is 0.210
# Test at Epoch 7 , AUC: 0.906634333368
# Training at Epoch 8 iteration 0, total loss is 0.399, proj loss is 0.262, recon loss is 0.005, classification loss is 0.133
# Training at Epoch 8 iteration 20, total loss is 0.297, proj loss is 0.128, recon loss is 0.005, classification loss is 0.164
# Training at Epoch 8 iteration 40, total loss is 0.292, proj loss is 0.132, recon loss is 0.005, classification loss is 0.155
# Training at Epoch 8 iteration 60, total loss is 0.331, proj loss is 0.191, recon loss is 0.005, classification loss is 0.134
# Training at Epoch 8 iteration 80, total loss is 0.265, proj loss is 0.064, recon loss is 0.005, classification loss is 0.196
# Training at Epoch 8 iteration 100, total loss is 0.347, proj loss is 0.219, recon loss is 0.005, classification loss is 0.123
# Training at Epoch 8 iteration 120, total loss is 0.290, proj loss is 0.132, recon loss is 0.005, classification loss is 0.153
# Training at Epoch 8 iteration 140, total loss is 0.289, proj loss is 0.087, recon loss is 0.005, classification loss is 0.198
# Training at Epoch 8 iteration 160, total loss is 0.250, proj loss is 0.081, recon loss is 0.005, classification loss is 0.164
# Training at Epoch 8 iteration 180, total loss is 0.286, proj loss is 0.039, recon loss is 0.005, classification loss is 0.242
# Training at Epoch 8 iteration 200, total loss is 0.296, proj loss is 0.096, recon loss is 0.005, classification loss is 0.196
# Test at Epoch 8 , AUC: 0.903129169278

# %%
plt.plot(loss_c)

# %%
from matplotlib import pyplot as plt
params = {'batch_size': 256,
              'shuffle': True,
              'num_workers': 6}

dataFolder = './data'

df_ddi = pd.read_csv('../data/SNAP/sup_test.csv')  # ddi dataframe drug1_smiles, drug2_smiles
labels_sup = df_ddi.label.values
test_set = supData(df_ddi.index.values, labels_sup, df_ddi)
test_generator_sup = data.DataLoader(test_set, **params)

model_nn = model_max

y_pred = []
y_label = []
model_nn.eval()
for i, (v_D, label) in tqdm(enumerate(test_generator_sup)):
    recon, code, score, Z_f, z_D = model_nn(v_D.float())
    m = torch.nn.Sigmoid()
    logits = torch.squeeze(m(score)).detach().cpu().numpy()
    label_ids = label.to('cpu').numpy()
    y_label = y_label + label_ids.flatten().tolist()
    y_pred = y_pred + logits.flatten().tolist()
# Out:
# 63it [13:01, 12.41s/it]

# %%
from sklearn.metrics import average_precision_score
average_precision_score(y_label, y_pred)
from sklearn.metrics import precision_recall_curve
from sklearn.utils.fixes import signature
average_precision = average_precision_score(y_label, y_pred)
precision, recall, _ = precision_recall_curve(y_label, y_pred)

# In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
step_kwargs = ({'step': 'post'}
               if 'step' in signature(plt.fill_between).parameters
               else {})
plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
average_precision
# Out:
# 0.8941994440870269

# %%
from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, auc, confusion_matrix, classification_report

fpr, tpr, thresholds = roc_curve(y_label, y_pred)
auc_score = auc(fpr, tpr)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Val (area = {:.3f})'.format(auc_score))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
